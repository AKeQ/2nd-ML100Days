# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = '../data/app-store-apple-data-set-10k-apps/'

# %%
f_app = os.path.join(dir_data, 'AppleStore.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: ../data/app-store-apple-data-set-10k-apps/AppleStore.csv
# RangeIndex(start=0, stop=7197, step=1)

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
app_train.shape
# Out:
# (7197, 17)

# %% [markdown]
# #### 列出所有欄位

# %%
app_train.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %% [markdown]
# #### 截取部分資料

# %%
app_train[['track_name', 'size_bytes']]
# Out:
#                                              track_name  size_bytes
# 0                                       PAC-MAN Premium   100788224
# 1                             Evernote - stay organized   158578688
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4                                                 Bible    92774400
# 5                                      Shanghai Mahjong    10485713
# 6                PayPal - Send and request money safely   227795968
# 7                               Pandora - Music & Radio   130242560
# 8                           PCalc - The Best Calculator    49250304
# 9                                           Ms. PAC-MAN    70023168
# 10                            Solitaire by MobilityWare    49618944
# 11                                     SCRABBLE Premium   227547136
# 12                 Google – Search made just for mobile   179979264
# 13                     Bank of America - Mobile Banking   160925696
# 14                                             FreeCell    55153664
# 15               TripAdvisor Hotels Flights Restaurants   207907840
# 16                                             Facebook   389879808
# 17       Yelp - Nearby Restaurants, Shopping & Services   167407616
# 18    Shazam - Discover music, artists, videos & lyrics   147093504
# 19                        Crash Bandicoot Nitro Kart 3D    10735026
# 20                                               iQuran    70707916
# 21                                          :) Sudoku +     6169600
# 22      Yahoo Sports - Teams, Scores, News & Highlights   130583552
# 23                            Mileage Log | Fahrtenbuch    71203840
# 24                          Cleartune - Chromatic Tuner    11423008
# 25            Lifesum – Inspiring healthy lifestyle app   188017664
# 26                                             Hangman.     4765696
# 27        iTranslate - Language Translator & Dictionary   287933440
# 28                                             TouchOSC     4263936
# 29                                           RadarScope   172772352
# ...                                                 ...         ...
# 7167                      脱出ゲーム　わたしをみつけて　-おじいさんとわたしの物語-   177498112
# 7168                      Escape from the frigid Igloo.    89188352
# 7169        Talking Santa - Video santa claus calls you    32685056
# 7170                                          CTFxCmoji    26077184
# 7171                    Room Escape Game - Santa's Room   143346688
# 7172                               Rescue the Enchanter   242505728
# 7173                                 My Diary - 你的名字非官方    18164736
# 7174  VR Thrills: Roller Coaster 360 (Google Cardboard)   169535488
# 7175   Santa Kids Hair Salon - Christmas Makeover Games    64244736
# 7176                                 Human Juggling Cup   184324096
# 7177                           Again - room escape game    33946624
# 7178                                  Saloons Unleashed   327731200
# 7179             Fam — Group video calling for iMessage   113382400
# 7180                   Laurie Hernandez the Human Emoji    94008320
# 7181                                               剑倚手游   178160640
# 7182                                  camera for filter     9362432
# 7183                                    Survivalcraft 2    57349120
# 7184                                    剑客情缘-高爆率高掉落天天疯玩   171944960
# 7185                                     问仙奇遇-新玩法新套装嗨到爆   208026624
# 7186                 脱出ゲーム - 書道教室 -  "漢字"の謎に満ちた部屋からの 脱出    85580800
# 7187                          Escape Game: illumination    52342784
# 7188       Demolition Derby Virtual Reality (VR) Racing   168774656
# 7189                         飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）   537462784
# 7190                       Add-Ons Studio for Minecraft    22999040
# 7191                         Plead the Fifth - The Game    27853824
# 7192                                              Kubik   126644224
# 7193                                  VR Roller-Coaster   120760320
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112
# 7195          VR Roller Coaster World - Virtual Reality    97235968
# 7196                       Escape the Sweet Shop Series    90898432
#
# [7197 rows x 2 columns]

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子
